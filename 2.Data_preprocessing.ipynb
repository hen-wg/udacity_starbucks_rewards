# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import math
import json
# % matplotlib inline
import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# ## Portfolio

# %%
portfolio.dtypes
# Out:
# reward         int64
# channels      object
# difficulty     int64
# duration       int64
# offer_type    object
# id            object
# dtype: object

# %%
# machine learning algorithms can only handle numerical features, change the channels column to dummy variables
# use channel column to create dummy variables
portfolio = pd.concat([portfolio, pd.get_dummies(portfolio['channels'].apply(pd.Series).stack()).sum(level=0)], axis=1)
# drop channel column
portfolio.drop('channels', axis=1, inplace=True)

# %%
portfolio.rename(columns={'id':'offer_id'})
# Out:
#    reward  difficulty  duration     offer_type  \
# 0      10          10         7           bogo
# 1      10          10         5           bogo
# 2       0           0         4  informational
# 3       5           5         7           bogo
# 4       5          20        10       discount
# 5       3           7         7       discount
# 6       2          10        10       discount
# 7       0           0         3  informational
# 8       5           5         5           bogo
# 9       2          10         7       discount
#
#                            offer_id  email  mobile  social  web
# 0  ae264e3637204a6fb9bb56bc8210ddfd      1       1       1    0
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      1       1       1    1
# 2  3f207df678b143eea3cee63160fa8bed      1       1       0    1
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9      1       1       0    1
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      1       0       0    1
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2      1       1       1    1
# 6  fafdcd668e3743c1bb461111dcafc2a4      1       1       1    1
# 7  5a8bc65990b245e5a138643cd4eb9837      1       1       1    0
# 8  f19421c1d4aa40978ebb69ca19b0e20d      1       1       1    1
# 9  2906b810c7d4411798c6938adc9daaa5      1       1       0    1

# %%
portfolio
# Out:
#    reward  difficulty  duration     offer_type  \
# 0      10          10         7           bogo
# 1      10          10         5           bogo
# 2       0           0         4  informational
# 3       5           5         7           bogo
# 4       5          20        10       discount
# 5       3           7         7       discount
# 6       2          10        10       discount
# 7       0           0         3  informational
# 8       5           5         5           bogo
# 9       2          10         7       discount
#
#                                  id  email  mobile  social  web
# 0  ae264e3637204a6fb9bb56bc8210ddfd      1       1       1    0
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      1       1       1    1
# 2  3f207df678b143eea3cee63160fa8bed      1       1       0    1
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9      1       1       0    1
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      1       0       0    1
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2      1       1       1    1
# 6  fafdcd668e3743c1bb461111dcafc2a4      1       1       1    1
# 7  5a8bc65990b245e5a138643cd4eb9837      1       1       1    0
# 8  f19421c1d4aa40978ebb69ca19b0e20d      1       1       1    1
# 9  2906b810c7d4411798c6938adc9daaa5      1       1       0    1

# %% [markdown]
# ## Profile

# %%
profile.dtypes
# Out:
# gender               object
# age                   int64
# id                   object
# became_member_on      int64
# income              float64
# dtype: object

# %%
# change the became_member_on column to datetime
profile['became_member_on'] = pd.to_datetime(profile['became_member_on'], format='%Y%m%d')

# %%
# machine learning algorithms cannot consume dates
# change became_member_on to number of days as a member 
profile['days_as_member'] = (datetime.datetime.today() - profile['became_member_on']).dt.days

# drop became_member_on column
profile.drop('became_member_on', axis=1, inplace=True)

# %%
# filter for all the customers who have income data and no gender data
profile[profile['gender'].isnull() & profile['income'].notnull()]
# Out:
# Empty DataFrame
# Columns: [gender, age, id, income, days_as_member]
# Index: []

# %%
profile[profile['income'].isnull() & profile['gender'].notnull()]
# Out:
# Empty DataFrame
# Columns: [gender, age, id, income, days_as_member]
# Index: []

# %% [markdown]
# NOTE: because there are only 4 features and all the rows with missing genders also have missing income values, we can drop these rows

# %%
profile[profile['age'] >= 118]
# Out:
#       gender  age                                id  income  days_as_member
# 0       None  118  68be06ca386d4c31939f3a4f0e3dd783     NaN            2290
# 2       None  118  38fe809add3b4fcf9315a9694bb96ff5     NaN            1775
# 4       None  118  a03223e636434f42ac4c3df47e8bac43     NaN            2117
# 6       None  118  8ec6ce2a7e7949b1bf142def7d0e0586     NaN            2065
# 7       None  118  68617ca6246f4fbc85e91a2a49552598     NaN            2058
# ...      ...  ...                               ...     ...             ...
# 16980   None  118  5c686d09ca4d475a8f750f2ba07e0440     NaN            2454
# 16982   None  118  d9ca82f550ac4ee58b6299cf1e5c824a     NaN            2593
# 16989   None  118  ca45ee1883624304bac1e4c8a114f045     NaN            1904
# 16991   None  118  a9a20fa8b5504360beb4e7c8712f8306     NaN            2683
# 16994   None  118  c02b10e8752c4d8e9b73f918558531f7     NaN            2719
#
# [2175 rows x 5 columns]

# %% [markdown]
# NOTE: it is also the same records with invalid age values, we will drop these columns.

# %%
profile.shape
# Out:
# (17000, 5)

# %%
# drop nan values
profile.dropna(inplace=True)

# %%
profile.shape
# Out:
# (14825, 5)

# %%
print(f"{17000-14825} records dropped")
# Out:
# 2175 records dropped

# %%
profile[profile['income'].isnull()]
# Out:
# Empty DataFrame
# Columns: [gender, age, id, income, days_as_member]
# Index: []

# %%
profile.head()
# Out:
#    gender  age                                id    income  days_as_member
# 1       F   55  0610b486422d4921ae7d2bf64640c50b  112000.0            2137
# 3       F   75  78afa995795e4d85b5d9ceeca43f5fef  100000.0            2204
# 5       M   68  e2127556f4f64592b11af22de27a7932   70000.0            1852
# 8       M   65  389bc3fa690240e798340f5a15918d5c   53000.0            1928
# 12      M   58  2eeac8d8feae4a8cad5a6af0499a211d   51000.0            2018

# %%
profile.gender.value_counts()
# Out:
# M    8484
# F    6129
# O     212
# Name: gender, dtype: int64

# %%
# machine learning algorithms can only handle numerical features, change the gender column to dummy variables
# create gender dummy variables
profile = pd.concat([profile, pd.get_dummies(profile['gender'].apply(pd.Series).stack()).sum(level=0)], axis=1)

# %%
# drop channel column
profile.drop('gender', axis=1, inplace=True)

# %%
profile
# Out:
#        age                                id    income  days_as_member  F  M  \
# 1       55  0610b486422d4921ae7d2bf64640c50b  112000.0            2137  1  0
# 3       75  78afa995795e4d85b5d9ceeca43f5fef  100000.0            2204  1  0
# 5       68  e2127556f4f64592b11af22de27a7932   70000.0            1852  0  1
# 8       65  389bc3fa690240e798340f5a15918d5c   53000.0            1928  0  1
# 12      58  2eeac8d8feae4a8cad5a6af0499a211d   51000.0            2018  0  1
# ...    ...                               ...       ...             ... .. ..
# 16995   45  6d5f3a774f3d4714ab0c092238f3a1d7   54000.0            1813  1  0
# 16996   61  2cb4f97358b841b9a9773a7aa05a9d77   72000.0            1774  0  1
# 16997   49  01d26f638c274aa0b965d24cefe3183f   73000.0            2307  0  1
# 16998   83  9dc1421481194dcd9400aec7c9ae6366   50000.0            2632  1  0
# 16999   62  e4052622e5ba45a8b96b59aba68cf068   82000.0            2130  1  0
#
#        O
# 1      0
# 3      0
# 5      0
# 8      0
# 12     0
# ...   ..
# 16995  0
# 16996  0
# 16997  0
# 16998  0
# 16999  0
#
# [14825 rows x 7 columns]

# %% [markdown]
# ## Transcript

# %%
transcript.dtypes
# Out:
# person    object
# event     object
# value     object
# time       int64
# dtype: object

# %%
transcript.tail()
# Out:
#                                   person        event  \
# 306529  b3a1272bc9904337b331bf348c3e8c17  transaction
# 306530  68213b08d99a4ae1b0dcb72aebd9aa35  transaction
# 306531  a00058cf10334a308c68e7631c529907  transaction
# 306532  76ddbd6576844afe811f1a3c0fbb5bec  transaction
# 306533  c02b10e8752c4d8e9b73f918558531f7  transaction
#
#                                  value  time
# 306529  {'amount': 1.5899999999999999}   714
# 306530                {'amount': 9.53}   714
# 306531                {'amount': 3.61}   714
# 306532  {'amount': 3.5300000000000002}   714
# 306533                {'amount': 4.05}   714

# %%
transcript[transcript.event == 'transaction']
# Out:
#                                   person        event  \
# 12654   02c083884c7d45b39cc68e1314fec56c  transaction
# 12657   9fa9ae8f57894cc9a3b8a9bbe0fc1b2f  transaction
# 12659   54890f68699049c2a04d415abc25e717  transaction
# 12670   b2f1cd155b864803ad8334cdf13c4bd2  transaction
# 12671   fe97aa22dd3e48c8b143116a8403dd52  transaction
# ...                                  ...          ...
# 306529  b3a1272bc9904337b331bf348c3e8c17  transaction
# 306530  68213b08d99a4ae1b0dcb72aebd9aa35  transaction
# 306531  a00058cf10334a308c68e7631c529907  transaction
# 306532  76ddbd6576844afe811f1a3c0fbb5bec  transaction
# 306533  c02b10e8752c4d8e9b73f918558531f7  transaction
#
#                                  value  time
# 12654   {'amount': 0.8300000000000001}     0
# 12657                {'amount': 34.56}     0
# 12659                {'amount': 13.23}     0
# 12670                {'amount': 19.51}     0
# 12671                {'amount': 18.97}     0
# ...                                ...   ...
# 306529  {'amount': 1.5899999999999999}   714
# 306530                {'amount': 9.53}   714
# 306531                {'amount': 3.61}   714
# 306532  {'amount': 3.5300000000000002}   714
# 306533                {'amount': 4.05}   714
#
# [138953 rows x 4 columns]

# %%
# drop duplicate records
transcript.drop_duplicates(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 2
#       1 # drop duplicate records
# ----> 2 transcript.drop_duplicates(inplace=True)
#
# File ~/wsl-repos/udacity_starbucks_rewards/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/wsl-repos/udacity_starbucks_rewards/venv/lib/python3.10/site-packages/pandas/core/frame.py:6669, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6667 inplace = validate_bool_kwarg(inplace, "inplace")
#    6668 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6669 duplicated = self.duplicated(subset, keep=keep)
#    6671 result = self[-duplicated]
#    6672 if ignore_index:
#
# File ~/wsl-repos/udacity_starbucks_rewards/venv/lib/python3.10/site-packages/pandas/core/frame.py:6811, in DataFrame.duplicated(self, subset, keep)
#    6809 else:
#    6810     vals = (col.values for name, col in self.items() if name in subset)
# -> 6811     labels, shape = map(list, zip(*map(f, vals)))
#    6813     ids = get_group_index(
#    6814         labels,
#    6815         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6819         xnull=False,
#    6820     )
#    6821     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~/wsl-repos/udacity_starbucks_rewards/venv/lib/python3.10/site-packages/pandas/core/frame.py:6779, in DataFrame.duplicated.<locals>.f(vals)
#    6778 def f(vals) -> tuple[np.ndarray, int]:
# -> 6779     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6780     return labels.astype("i8", copy=False), len(shape)
#
# File ~/wsl-repos/udacity_starbucks_rewards/venv/lib/python3.10/site-packages/pandas/core/algorithms.py:818, in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     815             # Don't modify (potentially user-provided) array
#     816             values = np.where(null_mask, na_value, values)
# --> 818     codes, uniques = factorize_array(
#     819         values,
#     820         na_sentinel=na_sentinel_arg,
#     821         size_hint=size_hint,
#     822     )
#     824 if sort and len(uniques) > 0:
#     825     if na_sentinel is None:
#     826         # TODO: Can remove when na_sentinel=na_sentinel as in TODO above
#
# File ~/wsl-repos/udacity_starbucks_rewards/venv/lib/python3.10/site-packages/pandas/core/algorithms.py:574, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     571 hash_klass, values = _get_hashtable_algo(values)
#     573 table = hash_klass(size_hint or len(values))
# --> 574 uniques, codes = table.factorize(
#     575     values,
#     576     na_sentinel=na_sentinel,
#     577     na_value=na_value,
#     578     mask=mask,
#     579     ignore_na=ignore_na,
#     580 )
#     582 # re-cast e.g. i8->dt64/td64, uint8->bool
#     583 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:5943, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:5857, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'dict'

# %%
# unpack the value column
transcript['offer_id'] = transcript['value'].apply(lambda x: x.get('offer_id'))
transcript['amount'] = transcript['value'].apply(lambda x: x.get('amount'))
transcript['offer id'] = transcript['value'].apply(lambda x: x.get('offer id'))
