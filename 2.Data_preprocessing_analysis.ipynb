# %% [markdown]
# # Data Preprocessing
# We want to build a model that predicts whether or not someone will respond to an offer. Many variables need to be changed to be numeric types for a machine learning model to process it. We also need to combine our data. Please see the steps required below for each of our datasets.

# %%
import pandas as pd
import numpy as np
import math
import json
# % matplotlib inline
import datetime
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# ## Portfolio

# %%
portfolio.dtypes
# Out:
# reward         int64
# channels      object
# difficulty     int64
# duration       int64
# offer_type    object
# id            object
# dtype: object

# %%
portfolio.head(5)
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10         7           bogo
# 1      10  [web, email, mobile, social]          10         5           bogo
# 2       0          [web, email, mobile]           0         4  informational
# 3       5          [web, email, mobile]           5         7           bogo
# 4       5                  [web, email]          20        10       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7

# %%
# machine learning algorithms can only handle numerical features, change the channels column to dummy variables
# use channel column to create dummy variables
portfolio = pd.concat([portfolio, pd.get_dummies(portfolio['channels'].apply(pd.Series).stack()).sum(level=0)], axis=1)
# drop channel column
portfolio.drop('channels', axis=1, inplace=True)

# %%
portfolio= portfolio.rename(columns={'id':'offer_id'})

# %%
portfolio.head()
# Out:
#    reward  difficulty  duration     offer_type  \
# 0      10          10         7           bogo
# 1      10          10         5           bogo
# 2       0           0         4  informational
# 3       5           5         7           bogo
# 4       5          20        10       discount
#
#                            offer_id  email  mobile  social  web
# 0  ae264e3637204a6fb9bb56bc8210ddfd      1       1       1    0
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      1       1       1    1
# 2  3f207df678b143eea3cee63160fa8bed      1       1       0    1
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9      1       1       0    1
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      1       0       0    1

# %% [markdown]
# ## Profile

# %%
profile.dtypes
# Out:
# gender               object
# age                   int64
# id                   object
# became_member_on      int64
# income              float64
# dtype: object

# %%
# change the became_member_on column to datetime
profile['became_member_on'] = pd.to_datetime(profile['became_member_on'], format='%Y%m%d')

# %%
# machine learning algorithms cannot consume dates
# change became_member_on to number of days as a member 
profile['days_as_member'] = (datetime.datetime.today() - profile['became_member_on']).dt.days

# drop became_member_on column
profile.drop('became_member_on', axis=1, inplace=True)

# %%
# filter for all the customers who have income data and no gender data
profile[profile['gender'].isnull() & profile['income'].notnull()]
# Out:
# Empty DataFrame
# Columns: [gender, age, id, income, days_as_member]
# Index: []

# %%
profile[profile['income'].isnull() & profile['gender'].notnull()]
# Out:
# Empty DataFrame
# Columns: [gender, age, id, income, days_as_member]
# Index: []

# %% [markdown]
# NOTE: because there are only 4 features and all the rows with missing genders also have missing income values, we can drop these rows

# %%
profile[profile['age'] >= 118]
# Out:
#       gender  age                                id  income  days_as_member
# 0       None  118  68be06ca386d4c31939f3a4f0e3dd783     NaN            2325
# 2       None  118  38fe809add3b4fcf9315a9694bb96ff5     NaN            1810
# 4       None  118  a03223e636434f42ac4c3df47e8bac43     NaN            2152
# 6       None  118  8ec6ce2a7e7949b1bf142def7d0e0586     NaN            2100
# 7       None  118  68617ca6246f4fbc85e91a2a49552598     NaN            2093
# ...      ...  ...                               ...     ...             ...
# 16980   None  118  5c686d09ca4d475a8f750f2ba07e0440     NaN            2489
# 16982   None  118  d9ca82f550ac4ee58b6299cf1e5c824a     NaN            2628
# 16989   None  118  ca45ee1883624304bac1e4c8a114f045     NaN            1939
# 16991   None  118  a9a20fa8b5504360beb4e7c8712f8306     NaN            2718
# 16994   None  118  c02b10e8752c4d8e9b73f918558531f7     NaN            2754
#
# [2175 rows x 5 columns]

# %% [markdown]
# NOTE: it is also the same records with invalid age values, we will drop these columns.

# %%
profile.shape
# Out:
# (17000, 5)

# %%
# drop nan values
profile.dropna(inplace=True)

# %%
profile.shape
# Out:
# (14825, 5)

# %%
print(f"{17000-14825} records dropped")
# Out:
# 2175 records dropped

# %%
profile[profile['income'].isnull()]
# Out:
# Empty DataFrame
# Columns: [gender, age, id, income, days_as_member]
# Index: []

# %%
profile.head()
# Out:
#    gender  age                                id    income  days_as_member
# 1       F   55  0610b486422d4921ae7d2bf64640c50b  112000.0            2172
# 3       F   75  78afa995795e4d85b5d9ceeca43f5fef  100000.0            2239
# 5       M   68  e2127556f4f64592b11af22de27a7932   70000.0            1887
# 8       M   65  389bc3fa690240e798340f5a15918d5c   53000.0            1963
# 12      M   58  2eeac8d8feae4a8cad5a6af0499a211d   51000.0            2053

# %%
profile.gender.value_counts()
# Out:
# M    8484
# F    6129
# O     212
# Name: gender, dtype: int64

# %%
# machine learning algorithms can only handle numerical features, change the gender column to dummy variables
# create gender dummy variables
profile = pd.concat([profile, pd.get_dummies(profile['gender'].apply(pd.Series).stack()).sum(level=0)], axis=1)

# %%
# drop channel column
profile.drop('gender', axis=1, inplace=True)

# %%
profile.head()
# Out:
#     age                                id    income  days_as_member  F  M  O
# 1    55  0610b486422d4921ae7d2bf64640c50b  112000.0            2172  1  0  0
# 3    75  78afa995795e4d85b5d9ceeca43f5fef  100000.0            2239  1  0  0
# 5    68  e2127556f4f64592b11af22de27a7932   70000.0            1887  0  1  0
# 8    65  389bc3fa690240e798340f5a15918d5c   53000.0            1963  0  1  0
# 12   58  2eeac8d8feae4a8cad5a6af0499a211d   51000.0            2053  0  1  0

# %%
profile= profile.rename(columns={'id':'user_id'})

# %%
profile.head()
# Out:
#     age                           user_id    income  days_as_member  F  M  O
# 1    55  0610b486422d4921ae7d2bf64640c50b  112000.0            2172  1  0  0
# 3    75  78afa995795e4d85b5d9ceeca43f5fef  100000.0            2239  1  0  0
# 5    68  e2127556f4f64592b11af22de27a7932   70000.0            1887  0  1  0
# 8    65  389bc3fa690240e798340f5a15918d5c   53000.0            1963  0  1  0
# 12   58  2eeac8d8feae4a8cad5a6af0499a211d   51000.0            2053  0  1  0

# %% [markdown]
# ## Transcript

# %%
transcript.dtypes
# Out:
# person    object
# event     object
# value     object
# time       int64
# dtype: object

# %%
transcript.tail()
# Out:
#                                   person        event  \
# 306529  b3a1272bc9904337b331bf348c3e8c17  transaction
# 306530  68213b08d99a4ae1b0dcb72aebd9aa35  transaction
# 306531  a00058cf10334a308c68e7631c529907  transaction
# 306532  76ddbd6576844afe811f1a3c0fbb5bec  transaction
# 306533  c02b10e8752c4d8e9b73f918558531f7  transaction
#
#                                  value  time
# 306529  {'amount': 1.5899999999999999}   714
# 306530                {'amount': 9.53}   714
# 306531                {'amount': 3.61}   714
# 306532  {'amount': 3.5300000000000002}   714
# 306533                {'amount': 4.05}   714

# %%
transcript.sample(n=5)
# Out:
#                                   person           event  \
# 160732  c2390da2832148358ec29931c0487885  offer received
# 179538  370c5f0ff5764c9898e22c51748be7fe     transaction
# 142937  49dbb5995ab543968648ffc5500c609c     transaction
# 38292   eaf82df1ddce4a1e87dbd946ffbf4a39     transaction
# 85971   6c5bbcee7e4e4e60b093c7b4ecee8309     transaction
#
#                                                    value  time
# 160732  {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}   408
# 179538                                  {'amount': 0.09}   432
# 142937                                  {'amount': 0.63}   378
# 38292                                   {'amount': 3.66}    84
# 85971                                   {'amount': 1.98}   216

# %%
# convert the json column to usable columns

# %%
# transcript['value_type'] = transcript['value'].apply(lambda x: list(x.keys())[0])
# transcript['value_details'] = transcript['value'].apply(lambda x: list(x.values())[0])
# transcript['value_details'] = transcript['value_details'].astype(str)
# this doesnt work for joining later

# %%
# unpack the value column
transcript['offer_id'] = transcript['value'].apply(lambda x: x.get('offer_id') or x.get('offer id'))
transcript['amount'] = transcript['value'].apply(lambda x: x.get('amount'))

# %%
# drop the value column
transcript.drop(columns=['value'], inplace=True)

# %%
# drop all the duplicate records
transcript.drop_duplicates(inplace=True)

# %% [markdown]
# ## Combining data

# %%
portfolio.head(2)
# Out:
#    reward  difficulty  duration offer_type                          offer_id  \
# 0      10          10         7       bogo  ae264e3637204a6fb9bb56bc8210ddfd
# 1      10          10         5       bogo  4d5c57ea9a6940dd891ad53e9dbe8da0
#
#    email  mobile  social  web
# 0      1       1       1    0
# 1      1       1       1    1

# %%
profile.head(2)
# Out:
#    age                           user_id    income  days_as_member  F  M  O
# 1   55  0610b486422d4921ae7d2bf64640c50b  112000.0            2172  1  0  0
# 3   75  78afa995795e4d85b5d9ceeca43f5fef  100000.0            2239  1  0  0

# %%
transcript.sample(n=5)
# Out:
#                                   person            event  time  \
# 274604  2956c29de4bb442cb1959389dfc541ca  offer completed   606
# 9185    bc8244e584fb4f06a55201e47b9c4664   offer received     0
# 110703  057f6741e0e0438e827cc0b18c601160      transaction   330
# 218587  0199681637524988a14245632b8376af     offer viewed   510
# 102638  8b70ca1f5f5a45bdac2ac2f990b71526      transaction   288
#
#                                 offer_id  amount
# 274604  fafdcd668e3743c1bb461111dcafc2a4     NaN
# 9185    f19421c1d4aa40978ebb69ca19b0e20d     NaN
# 110703                              None   22.35
# 218587  ae264e3637204a6fb9bb56bc8210ddfd     NaN
# 102638                              None   47.26

# %%
transcript.shape
# Out:
# (306137, 5)

# %%
# combine datasets on corresponding ids
combined = pd.merge(transcript, profile, left_on= 'person', right_on='user_id', how='left')
combined = pd.merge(combined, portfolio, on = 'offer_id', how='left')
combined.sample(n=5)
# Out:
#                                   person            event  time  \
# 216529  974426519c1f4e6e876a7bffeec78254      transaction   504
# 134700  bca5a5ccd80d4c438ee767d2da84ebaa     offer viewed   354
# 241241  d0de5df4a59845fc865659b10adfb80e     offer viewed   564
# 225260  bcfbadce76f34099a68a10adc7f86c3b  offer completed   522
# 106264  0fc637442b954432b13c360af61d4256      transaction   306
#
#                                 offer_id  amount   age  \
# 216529                              None    1.27   NaN
# 134700  f19421c1d4aa40978ebb69ca19b0e20d     NaN  49.0
# 241241  f19421c1d4aa40978ebb69ca19b0e20d     NaN  35.0
# 225260  2906b810c7d4411798c6938adc9daaa5     NaN  62.0
# 106264                              None   12.98  43.0
#
#                                  user_id   income  days_as_member    F    M  \
# 216529                               NaN      NaN             NaN  NaN  NaN
# 134700  bca5a5ccd80d4c438ee767d2da84ebaa  36000.0          1868.0  0.0  1.0
# 241241  d0de5df4a59845fc865659b10adfb80e  74000.0          2074.0  1.0  0.0
# 225260  bcfbadce76f34099a68a10adc7f86c3b  84000.0          2409.0  1.0  0.0
# 106264  0fc637442b954432b13c360af61d4256  57000.0          2884.0  1.0  0.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 216529  NaN     NaN         NaN       NaN        NaN    NaN     NaN     NaN
# 134700  0.0     5.0         5.0       5.0       bogo    1.0     1.0     1.0
# 241241  0.0     5.0         5.0       5.0       bogo    1.0     1.0     1.0
# 225260  0.0     2.0        10.0       7.0   discount    1.0     1.0     0.0
# 106264  0.0     NaN         NaN       NaN        NaN    NaN     NaN     NaN
#
#         web
# 216529  NaN
# 134700  1.0
# 241241  1.0
# 225260  1.0
# 106264  NaN

# %%
# no records gained, correct
combined.shape
# Out:
# (306137, 20)

# %%
# find all the nan values
combined.isnull().sum()
# Out:
# person                 0
# event                  0
# time                   0
# offer_id          138953
# amount            167184
# age                33749
# user_id            33749
# income             33749
# days_as_member     33749
# F                  33749
# M                  33749
# O                  33749
# reward            138953
# difficulty        138953
# duration          138953
# offer_type        138953
# email             138953
# mobile            138953
# social            138953
# web               138953
# dtype: int64

# %%
# there are no users associated with these records
combined[combined['user_id'].isnull()].sample(n=15)
# Out:
#                                   person            event  time  \
# 296685  31d6a951d92b407fa8fa127aa0bf0e7e  offer completed   672
# 243347  8fdb780cf1844206bd605313965cacf9      transaction   570
# 289722  9f3a4c78181f4a138f0130ea027a2f3d     offer viewed   648
# 4039    b9d07d53d8944f4b865990b52e532710   offer received     0
# 231168  f092d429217c4a18a2c326971bbc4b7e      transaction   534
# 216164  5135913f61fa4f15b35c45c01ab9fab3     offer viewed   504
# 122021  97a94283e9a84bb2907d7fb3402c5e26   offer received   336
# 160660  29b4ba3741f040de95cba6ac2e436fa9   offer received   408
# 210417  143d05b3029c483a80c3ebb4fa3aa620   offer received   504
# 44056   75c1b4d22fd24b35b2f0a52fd8ff1735      transaction   108
# 215526  1c3df5c135b541eb8f5ac99266e78b47     offer viewed   504
# 290578  3407ea7b3da64a98848f6c2fadfc0c69      transaction   648
# 43591   e1251ca419a84273a8a974fe61d3c69e      transaction   108
# 258082  c02340ed0fb4448b9a651f643fddac95      transaction   576
# 119887  c42e31b92abd41368be7ed1cf0a7ac46   offer received   336
#
#                                 offer_id  amount  age user_id  income  \
# 296685  2906b810c7d4411798c6938adc9daaa5     NaN  NaN     NaN     NaN
# 243347                              None    1.01  NaN     NaN     NaN
# 289722  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN  NaN     NaN     NaN
# 4039    3f207df678b143eea3cee63160fa8bed     NaN  NaN     NaN     NaN
# 231168                              None    0.36  NaN     NaN     NaN
# 216164  fafdcd668e3743c1bb461111dcafc2a4     NaN  NaN     NaN     NaN
# 122021  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN  NaN     NaN     NaN
# 160660  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN  NaN     NaN     NaN
# 210417  5a8bc65990b245e5a138643cd4eb9837     NaN  NaN     NaN     NaN
# 44056                               None    2.48  NaN     NaN     NaN
# 215526  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN  NaN     NaN     NaN
# 290578                              None    2.50  NaN     NaN     NaN
# 43591                               None    0.59  NaN     NaN     NaN
# 258082                              None    7.83  NaN     NaN     NaN
# 119887  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN  NaN     NaN     NaN
#
#         days_as_member   F   M   O  reward  difficulty  duration  \
# 296685             NaN NaN NaN NaN     2.0        10.0       7.0
# 243347             NaN NaN NaN NaN     NaN         NaN       NaN
# 289722             NaN NaN NaN NaN     5.0        20.0      10.0
# 4039               NaN NaN NaN NaN     0.0         0.0       4.0
# 231168             NaN NaN NaN NaN     NaN         NaN       NaN
# 216164             NaN NaN NaN NaN     2.0        10.0      10.0
# 122021             NaN NaN NaN NaN     5.0        20.0      10.0
# 160660             NaN NaN NaN NaN     3.0         7.0       7.0
# 210417             NaN NaN NaN NaN     0.0         0.0       3.0
# 44056              NaN NaN NaN NaN     NaN         NaN       NaN
# 215526             NaN NaN NaN NaN     5.0         5.0       7.0
# 290578             NaN NaN NaN NaN     NaN         NaN       NaN
# 43591              NaN NaN NaN NaN     NaN         NaN       NaN
# 258082             NaN NaN NaN NaN     NaN         NaN       NaN
# 119887             NaN NaN NaN NaN     5.0        20.0      10.0
#
#            offer_type  email  mobile  social  web
# 296685       discount    1.0     1.0     0.0  1.0
# 243347            NaN    NaN     NaN     NaN  NaN
# 289722       discount    1.0     0.0     0.0  1.0
# 4039    informational    1.0     1.0     0.0  1.0
# 231168            NaN    NaN     NaN     NaN  NaN
# 216164       discount    1.0     1.0     1.0  1.0
# 122021       discount    1.0     0.0     0.0  1.0
# 160660       discount    1.0     1.0     1.0  1.0
# 210417  informational    1.0     1.0     1.0  0.0
# 44056             NaN    NaN     NaN     NaN  NaN
# 215526           bogo    1.0     1.0     0.0  1.0
# 290578            NaN    NaN     NaN     NaN  NaN
# 43591             NaN    NaN     NaN     NaN  NaN
# 258082            NaN    NaN     NaN     NaN  NaN
# 119887       discount    1.0     0.0     0.0  1.0

# %%
profile[profile.user_id == '5ae36f912be1492199ec2da838cc6dda']
# Out:
# Empty DataFrame
# Columns: [age, user_id, income, days_as_member, F, M, O]
# Index: []

# %%
# since we are interested in how users respond to offers, we can drop all the records where there is no user associated
combined.dropna(subset=['user_id'], inplace=True)

# %%
# all transaction records dont correlate with any offers necessarily (no direct link) do we need to keep them?
combined[combined['reward'].isnull()].sample(n=15)
# Out:
#                                   person        event  time offer_id  amount  \
# 304722  c1d6f806a92c46fdaacaca6b9c8d2e18  transaction   708     None   29.42
# 302656  35dd2c597c7e43d8b8c53ade81e8350f  transaction   696     None    4.11
# 147142  8bdec7a2b2264f52b7d3e168a291f429  transaction   390     None   21.48
# 41982   04362cece3104f4ebcb3d49ef0bc7e9c  transaction    96     None    2.32
# 194505  5a8427053973447e9f888e58b2ced8b2  transaction   474     None    2.20
# 265512  e242bb9c734c4c6093feadfd95cf5e87  transaction   588     None   38.66
# 25622   48c1f1b492d3451b804b81877bf957f5  transaction    30     None   20.64
# 26226   de8ea15f5f0545b6b45df1a7ae2dca11  transaction    36     None    6.17
# 233313  61767761f4f44c368b5b069170b28bd6  transaction   540     None   34.78
# 173244  c79b5783fe67458d92e8559aa5e36da0  transaction   420     None    1.41
# 239959  20e6b5b7907a41d589576012963bde5d  transaction   558     None   23.69
# 79801   bdf569412b3542459ee5de4a6e6e01c8  transaction   198     None   11.18
# 13561   3c2f772174ea4c4fa501a2275a614876  transaction     0     None   10.25
# 71314   5bfda10afe2846a6980b72988b28d144  transaction   174     None   13.47
# 300748  5e60c6aa3b834e44b822ea43a3efea26  transaction   690     None    2.78
#
#          age                           user_id    income  days_as_member    F  \
# 304722  46.0  c1d6f806a92c46fdaacaca6b9c8d2e18   78000.0          1852.0  0.0
# 302656  22.0  35dd2c597c7e43d8b8c53ade81e8350f   31000.0          1943.0  1.0
# 147142  45.0  8bdec7a2b2264f52b7d3e168a291f429   66000.0          2088.0  1.0
# 41982   47.0  04362cece3104f4ebcb3d49ef0bc7e9c   38000.0          2808.0  0.0
# 194505  38.0  5a8427053973447e9f888e58b2ced8b2   73000.0          1934.0  0.0
# 265512  90.0  e242bb9c734c4c6093feadfd95cf5e87   71000.0          1852.0  1.0
# 25622   67.0  48c1f1b492d3451b804b81877bf957f5   77000.0          1946.0  0.0
# 26226   46.0  de8ea15f5f0545b6b45df1a7ae2dca11   32000.0          2086.0  0.0
# 233313  70.0  61767761f4f44c368b5b069170b28bd6  114000.0          2813.0  0.0
# 173244  88.0  c79b5783fe67458d92e8559aa5e36da0   32000.0          2403.0  1.0
# 239959  44.0  20e6b5b7907a41d589576012963bde5d   56000.0          2710.0  0.0
# 79801   78.0  bdf569412b3542459ee5de4a6e6e01c8   35000.0          1801.0  0.0
# 13561   45.0  3c2f772174ea4c4fa501a2275a614876   35000.0          2108.0  0.0
# 71314   89.0  5bfda10afe2846a6980b72988b28d144   52000.0          2604.0  0.0
# 300748  59.0  5e60c6aa3b834e44b822ea43a3efea26   55000.0          3140.0  0.0
#
#           M    O  reward  difficulty  duration offer_type  email  mobile  \
# 304722  1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 302656  0.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 147142  0.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 41982   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 194505  1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 265512  0.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 25622   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 26226   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 233313  1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 173244  0.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 239959  1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 79801   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 13561   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 71314   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 300748  1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
#
#         social  web
# 304722     NaN  NaN
# 302656     NaN  NaN
# 147142     NaN  NaN
# 41982      NaN  NaN
# 194505     NaN  NaN
# 265512     NaN  NaN
# 25622      NaN  NaN
# 26226      NaN  NaN
# 233313     NaN  NaN
# 173244     NaN  NaN
# 239959     NaN  NaN
# 79801      NaN  NaN
# 13561      NaN  NaN
# 71314      NaN  NaN
# 300748     NaN  NaN

# %%
# find all the values where amount is null
combined[combined['amount'].isnull()].event.value_counts()
# this is expected as amount null for offer records
# Out:
# offer received     66501
# offer viewed       49860
# offer completed    32070
# Name: event, dtype: int64

# %%
# find all the values where offer_id is null
combined[combined['offer_id'].isnull()].event.value_counts()
# this is expected as offer_id null for transaction records
# Out:
# transaction    123957
# Name: event, dtype: int64

# %% [markdown]
# ### Split transaction and offer records for analysis

# %%
# find all the nan values
combined.isnull().sum()
# Out:
# person                 0
# event                  0
# time                   0
# offer_id          123957
# amount            148431
# age                    0
# user_id                0
# income                 0
# days_as_member         0
# F                      0
# M                      0
# O                      0
# reward            123957
# difficulty        123957
# duration          123957
# offer_type        123957
# email             123957
# mobile            123957
# social            123957
# web               123957
# dtype: int64

# %%
# split the data into offer and transaction records
offer_df = combined[combined['offer_id'].notnull()]
transaction_df = combined[combined['offer_id'].isnull()]

# %%
print(combined.shape)
print(offer_df.shape)
print(transaction_df.shape)
# Out:
# (272388, 20)
# (148431, 20)
# (123957, 20)

# %% [markdown]
# #### Transaction records

# %%
transaction_df.sample(n=5)
# Out:
#                                   person        event  time offer_id  amount  \
# 185813  cc35fd7b202a43d19eddbec7b76e01ca  transaction   450     None   17.09
# 136187  4bdbd489583245e6a3a39456dccfc1d2  transaction   360     None    4.08
# 35571   bf60d102f38c4f2aacb09c2df487b7fc  transaction    72     None    0.34
# 72296   c8c44530553d43e4aae1edf97153cf38  transaction   180     None   15.03
# 295884  fd375e03ad394a7bb85b62eb15263f14  transaction   666     None   16.79
#
#          age                           user_id    income  days_as_member    F  \
# 185813  41.0  cc35fd7b202a43d19eddbec7b76e01ca   76000.0          2299.0  0.0
# 136187  21.0  4bdbd489583245e6a3a39456dccfc1d2   71000.0          2784.0  0.0
# 35571   53.0  bf60d102f38c4f2aacb09c2df487b7fc   60000.0          1903.0  0.0
# 72296   92.0  c8c44530553d43e4aae1edf97153cf38  113000.0          1851.0  0.0
# 295884  27.0  fd375e03ad394a7bb85b62eb15263f14   53000.0          2721.0  1.0
#
#           M    O  reward  difficulty  duration offer_type  email  mobile  \
# 185813  1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 136187  1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 35571   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 72296   1.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
# 295884  0.0  0.0     NaN         NaN       NaN        NaN    NaN     NaN
#
#         social  web
# 185813     NaN  NaN
# 136187     NaN  NaN
# 35571      NaN  NaN
# 72296      NaN  NaN
# 295884     NaN  NaN

# %%
# drop all the id columns as we do not need them for analysis
transaction_df.drop(columns=['person', 'offer_id'], inplace=True)
# Out:
# /tmp/ipykernel_572/2794338413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_df.drop(columns=['person', 'offer_id'], inplace=True)

# %%
# drop all the offer related columns not related to transactions (nan values)
transaction_df.drop(columns=['reward', 'difficulty', 'duration', 'offer_type', 'email', 'mobile', 'social', 'web'], inplace=True)
# Out:
# /tmp/ipykernel_572/1292048054.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_df.drop(columns=['reward', 'difficulty', 'duration', 'offer_type', 'email', 'mobile', 'social', 'web'], inplace=True)

# %%
transaction_df.head()
# Out:
#              event  time  amount   age                           user_id  \
# 12654  transaction     0    0.83  20.0  02c083884c7d45b39cc68e1314fec56c
# 12657  transaction     0   34.56  42.0  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f
# 12659  transaction     0   13.23  36.0  54890f68699049c2a04d415abc25e717
# 12670  transaction     0   19.51  55.0  b2f1cd155b864803ad8334cdf13c4bd2
# 12671  transaction     0   18.97  39.0  fe97aa22dd3e48c8b143116a8403dd52
#
#         income  days_as_member    F    M    O
# 12654  30000.0          2541.0  1.0  0.0  0.0
# 12657  96000.0          2717.0  0.0  1.0  0.0
# 12659  56000.0          2006.0  0.0  1.0  0.0
# 12670  94000.0          2079.0  1.0  0.0  0.0
# 12671  67000.0          2017.0  1.0  0.0  0.0

# %% [markdown]
# #### Offer records

# %%
offer_df.sample(n=5)
# Out:
#                                   person            event  time  \
# 71597   e31bac27c3554312ba7b3db96d81e70f     offer viewed   174
# 61866   06d34b0fb66e4feea9b2c765755a8e1f   offer received   168
# 163530  e25ba3813b224ea894e9d5bdd9f1bd64     offer viewed   408
# 211143  7c26e974fad34c159fbd3804e82e701e   offer received   504
# 268446  c9b534cdac834e5d9853828816300e57  offer completed   588
#
#                                 offer_id  amount   age  \
# 71597   4d5c57ea9a6940dd891ad53e9dbe8da0     NaN  31.0
# 61866   9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN  65.0
# 163530  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN  49.0
# 211143  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN  41.0
# 268446  f19421c1d4aa40978ebb69ca19b0e20d     NaN  55.0
#
#                                  user_id   income  days_as_member    F    M  \
# 71597   e31bac27c3554312ba7b3db96d81e70f  73000.0          2157.0  1.0  0.0
# 61866   06d34b0fb66e4feea9b2c765755a8e1f  82000.0          2101.0  0.0  1.0
# 163530  e25ba3813b224ea894e9d5bdd9f1bd64  65000.0          1980.0  0.0  1.0
# 211143  7c26e974fad34c159fbd3804e82e701e  59000.0          2157.0  0.0  1.0
# 268446  c9b534cdac834e5d9853828816300e57  53000.0          2836.0  1.0  0.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 71597   0.0    10.0        10.0       5.0       bogo    1.0     1.0     1.0
# 61866   0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 163530  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 211143  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 268446  0.0     5.0         5.0       5.0       bogo    1.0     1.0     1.0
#
#         web
# 71597   1.0
# 61866   1.0
# 163530  1.0
# 211143  1.0
# 268446  1.0

# %%
# drop all the transactions related columns not related to offers (nan values)
offer_df.drop(columns=['amount'], inplace=True)
offer_df.drop(columns=['person'], inplace=True)

# the time column is no of interesting to us, we can drop it
# offer_df.drop(columns=['time'], inplace=True)
# Out:
# /tmp/ipykernel_572/3663222115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offer_df.drop(columns=['amount'], inplace=True)
# /tmp/ipykernel_572/3663222115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offer_df.drop(columns=['person'], inplace=True)

# %%
portfolio
# Out:
#    reward  difficulty  duration     offer_type  \
# 0      10          10         7           bogo
# 1      10          10         5           bogo
# 2       0           0         4  informational
# 3       5           5         7           bogo
# 4       5          20        10       discount
# 5       3           7         7       discount
# 6       2          10        10       discount
# 7       0           0         3  informational
# 8       5           5         5           bogo
# 9       2          10         7       discount
#
#                            offer_id  email  mobile  social  web
# 0  ae264e3637204a6fb9bb56bc8210ddfd      1       1       1    0
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      1       1       1    1
# 2  3f207df678b143eea3cee63160fa8bed      1       1       0    1
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9      1       1       0    1
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      1       0       0    1
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2      1       1       1    1
# 6  fafdcd668e3743c1bb461111dcafc2a4      1       1       1    1
# 7  5a8bc65990b245e5a138643cd4eb9837      1       1       1    0
# 8  f19421c1d4aa40978ebb69ca19b0e20d      1       1       1    1
# 9  2906b810c7d4411798c6938adc9daaa5      1       1       0    1

# %%
offer_df[offer_df['offer_type'] == 'informational'].event.value_counts()
# Out:
# offer received    13300
# offer viewed       9360
# Name: event, dtype: int64

# %%
# informational offers are never completed, so we can drop them 
offer_df = offer_df[offer_df['offer_type'] != 'informational']

# %%
offer_df.sample(n=5)
# Out:
#                  event  time                          offer_id   age  \
# 251424  offer received   576  0b1e1539f2cc45b7b9fa7c272da2e1d7  63.0
# 2901    offer received     0  0b1e1539f2cc45b7b9fa7c272da2e1d7  65.0
# 217672    offer viewed   504  fafdcd668e3743c1bb461111dcafc2a4  44.0
# 257606  offer received   576  2298d6c36e964ae4a3e7e9706d1fb8c2  64.0
# 15324     offer viewed     0  4d5c57ea9a6940dd891ad53e9dbe8da0  43.0
#
#                                  user_id   income  days_as_member    F    M  \
# 251424  61426a58378543e0b56b2836dc94967d  88000.0          1887.0  1.0  0.0
# 2901    7378619969094009af10e2097b4a5f76  53000.0          3368.0  0.0  1.0
# 217672  234f3b42e14245349935d57b937300dd  39000.0          2039.0  0.0  1.0
# 257606  efba45d36ae340838b34c74b9ebb1dc2  57000.0          2805.0  0.0  1.0
# 15324   f9269e4540b84e6da9ff8c351ec3d463  69000.0          2631.0  1.0  0.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 251424  0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 2901    0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 217672  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 257606  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 15324   0.0    10.0        10.0       5.0       bogo    1.0     1.0     1.0
#
#         web
# 251424  1.0
# 2901    1.0
# 217672  1.0
# 257606  1.0
# 15324   1.0

# %%
offer_df[(offer_df.user_id == 'bea062a97557458a97f3e2df8d87755a') & (offer_df.offer_id == '4d5c57ea9a6940dd891ad53e9dbe8da0')]
# Out:
#                   event  time                          offer_id   age  \
# 206535   offer received   504  4d5c57ea9a6940dd891ad53e9dbe8da0  69.0
# 215894     offer viewed   504  4d5c57ea9a6940dd891ad53e9dbe8da0  69.0
# 231216  offer completed   534  4d5c57ea9a6940dd891ad53e9dbe8da0  69.0
#
#                                  user_id   income  days_as_member    F    M  \
# 206535  bea062a97557458a97f3e2df8d87755a  99000.0          2328.0  1.0  0.0
# 215894  bea062a97557458a97f3e2df8d87755a  99000.0          2328.0  1.0  0.0
# 231216  bea062a97557458a97f3e2df8d87755a  99000.0          2328.0  1.0  0.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 206535  0.0    10.0        10.0       5.0       bogo    1.0     1.0     1.0
# 215894  0.0    10.0        10.0       5.0       bogo    1.0     1.0     1.0
# 231216  0.0    10.0        10.0       5.0       bogo    1.0     1.0     1.0
#
#         web
# 206535  1.0
# 215894  1.0
# 231216  1.0

# %%
# use the event column to create dummy variables
offer_complete_df = pd.concat([offer_df, pd.get_dummies(offer_df['event'].apply(pd.Series).stack()).sum(level=0)], axis=1)
# rename offer completed column to offer_completed, offer received to offer_received, offer viewed to offer_viewed
offer_complete_df.rename(columns={'offer completed':'offer_completed', 'offer received':'offer_received', 'offer viewed':'offer_viewed'}, inplace=True)

# %%
offer_complete_df[(offer_complete_df.user_id == 'bea062a97557458a97f3e2df8d87755a') & (offer_complete_df.offer_id == '4d5c57ea9a6940dd891ad53e9dbe8da0')]
# Out:
#                   event  time                          offer_id   age  \
# 206535   offer received   504  4d5c57ea9a6940dd891ad53e9dbe8da0  69.0
# 215894     offer viewed   504  4d5c57ea9a6940dd891ad53e9dbe8da0  69.0
# 231216  offer completed   534  4d5c57ea9a6940dd891ad53e9dbe8da0  69.0
#
#                                  user_id   income  days_as_member    F    M  \
# 206535  bea062a97557458a97f3e2df8d87755a  99000.0          2328.0  1.0  0.0
# 215894  bea062a97557458a97f3e2df8d87755a  99000.0          2328.0  1.0  0.0
# 231216  bea062a97557458a97f3e2df8d87755a  99000.0          2328.0  1.0  0.0
#
#           O  ...  difficulty  duration  offer_type email  mobile  social  web  \
# 206535  0.0  ...        10.0       5.0        bogo   1.0     1.0     1.0  1.0
# 215894  0.0  ...        10.0       5.0        bogo   1.0     1.0     1.0  1.0
# 231216  0.0  ...        10.0       5.0        bogo   1.0     1.0     1.0  1.0
#
#         offer_completed  offer_received  offer_viewed
# 206535                0               1             0
# 215894                0               0             1
# 231216                1               0             0
#
# [3 rows x 21 columns]

# %%
# group by user_id and offer_id and sum the dummy variables
# offer_complete_df = offer_complete_df.groupby(['user_id', 'offer_id']).sum().reset_index()
# offer_df['combined_id'] = offer_df.apply(lambda x: x['user_id'] + x['offer_id'], axis=1)
# grp = offer_df.groupby('combined_id')
# grp.get_group('d3355ffcdb58449f9497fd76a879fbf2f19421c1d4aa40978ebb69ca19b0e20d')

# %%
# create a combined id to group the data by
# we will use these groups and logic to see if an offer that was viewed was also completed
offer_complete_df['combined_id'] = offer_complete_df.apply(lambda x: x['user_id'] + x['offer_id'], axis=1)
combined_id_map = offer_complete_df.groupby('combined_id')

# %%
def offer_viewed_and_completed( row, combined_id_map):

    if row['event'] != 'offer viewed':
        return 0
    
    combined_id = row['user_id'] + row['offer_id']
    filtered_rows = combined_id_map.get_group(combined_id)

    # find the previous offer received event
    previous_offer_received = filtered_rows[(filtered_rows['time'] <= row['time']) & (filtered_rows['event'] == 'offer received')].tail(1)
    # find the next offer completed event
    next_offer_completed = filtered_rows[(filtered_rows['time'] >= row['time']) & (filtered_rows['event'] == 'offer completed')].head(1)

    if previous_offer_received.shape[0] == 0 or next_offer_completed.shape[0] == 0:
        return 0

    if (next_offer_completed['time'].iloc[0] - previous_offer_received['time'].iloc[0] < 24 * row['duration']):
        return 1
    
    return 0

offer_complete_df['offer_viewed_and_completed'] = offer_complete_df.apply(lambda x: offer_viewed_and_completed(x, combined_id_map), axis=1)

# %%
offer_complete_df[offer_complete_df['event'] == 'offer viewed'].sample(n=5)
# Out:
#                event  time                          offer_id   age  \
# 261301  offer viewed   576  4d5c57ea9a6940dd891ad53e9dbe8da0  52.0
# 188534  offer viewed   456  f19421c1d4aa40978ebb69ca19b0e20d  93.0
# 304198  offer viewed   708  9b98b8c7a33c4b65b9aebfe6a799e6d9  41.0
# 260007  offer viewed   576  2298d6c36e964ae4a3e7e9706d1fb8c2  71.0
# 273244  offer viewed   600  f19421c1d4aa40978ebb69ca19b0e20d  72.0
#
#                                  user_id   income  days_as_member    F    M  \
# 261301  5532539d40724979849cc7b6e8cda9a9  58000.0          2520.0  1.0  0.0
# 188534  bfc1e0be52a141b5a89f3410d5f9eb37  73000.0          2111.0  1.0  0.0
# 304198  69f965c1424d4b479a66639ea4e92285  68000.0          2625.0  0.0  1.0
# 260007  3381f8550e8944c89cdadf97a3461823  52000.0          2278.0  0.0  1.0
# 273244  3706f0e6065f445d8cf6ee400e5ecfb8  97000.0          2343.0  1.0  0.0
#
#           O  ...  offer_type  email  mobile social  web  offer_completed  \
# 261301  0.0  ...        bogo    1.0     1.0    1.0  1.0                0
# 188534  0.0  ...        bogo    1.0     1.0    1.0  1.0                0
# 304198  0.0  ...        bogo    1.0     1.0    0.0  1.0                0
# 260007  0.0  ...    discount    1.0     1.0    1.0  1.0                0
# 273244  0.0  ...        bogo    1.0     1.0    1.0  1.0                0
#
#         offer_received  offer_viewed  \
# 261301               0             1
# 188534               0             1
# 304198               0             1
# 260007               0             1
# 273244               0             1
#
#                                               combined_id  \
# 261301  5532539d40724979849cc7b6e8cda9a94d5c57ea9a6940...
# 188534  bfc1e0be52a141b5a89f3410d5f9eb37f19421c1d4aa40...
# 304198  69f965c1424d4b479a66639ea4e922859b98b8c7a33c4b...
# 260007  3381f8550e8944c89cdadf97a34618232298d6c36e964a...
# 273244  3706f0e6065f445d8cf6ee400e5ecfb8f19421c1d4aa40...
#
#         offer_viewed_and_completed
# 261301                           1
# 188534                           0
# 304198                           0
# 260007                           1
# 273244                           0
#
# [5 rows x 23 columns]

# %%
offer_complete_df[(offer_complete_df.user_id == '5532539d40724979849cc7b6e8cda9a9') & (offer_complete_df.offer_id == '4d5c57ea9a6940dd891ad53e9dbe8da0')]
# Out:
#                   event  time                          offer_id   age  \
# 255864   offer received   576  4d5c57ea9a6940dd891ad53e9dbe8da0  52.0
# 261301     offer viewed   576  4d5c57ea9a6940dd891ad53e9dbe8da0  52.0
# 268148  offer completed   588  4d5c57ea9a6940dd891ad53e9dbe8da0  52.0
#
#                                  user_id   income  days_as_member    F    M  \
# 255864  5532539d40724979849cc7b6e8cda9a9  58000.0          2520.0  1.0  0.0
# 261301  5532539d40724979849cc7b6e8cda9a9  58000.0          2520.0  1.0  0.0
# 268148  5532539d40724979849cc7b6e8cda9a9  58000.0          2520.0  1.0  0.0
#
#           O  ...  offer_type  email  mobile social  web  offer_completed  \
# 255864  0.0  ...        bogo    1.0     1.0    1.0  1.0                0
# 261301  0.0  ...        bogo    1.0     1.0    1.0  1.0                0
# 268148  0.0  ...        bogo    1.0     1.0    1.0  1.0                1
#
#         offer_received  offer_viewed  \
# 255864               1             0
# 261301               0             1
# 268148               0             0
#
#                                               combined_id  \
# 255864  5532539d40724979849cc7b6e8cda9a94d5c57ea9a6940...
# 261301  5532539d40724979849cc7b6e8cda9a94d5c57ea9a6940...
# 268148  5532539d40724979849cc7b6e8cda9a94d5c57ea9a6940...
#
#         offer_viewed_and_completed
# 255864                           0
# 261301                           1
# 268148                           0
#
# [3 rows x 23 columns]

# %%
# drop all the events that are offer received
# offer_df = offer_df[offer_df['event'] != 'offer received']
# drop event column
# offer_complete_df.drop('event', axis=1, inplace=True)

# %%
# we not have a single record for each user and offer which indicates if an offer was received, viewed and completed or not

# %%
# as we are only interested in offers that were viewed and then completed, we can drop all the records where viewed is 0
offer_complete_df = offer_complete_df[offer_complete_df['offer_viewed'] != 0]

# %%
# the offer received column is no longer needed, they are all 1
offer_complete_df.drop(columns=['offer_received'], inplace=True)
# Out:
# /tmp/ipykernel_148411/2592021891.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offer_complete_df.drop(columns=['offer_received'], inplace=True)

# %% [markdown]
# #### Multiple user ID/offers investigation

# %%
offer_complete_df.offer_received.value_counts()
# Out:
# 0    72570
# 1    53201
# Name: offer_received, dtype: int64

# %%
offer_complete_df[offer_complete_df.offer_completed>1]
# Out:
#                                 user_id                          offer_id  \
# 8      0020c2b971eb4e9188eac86d93036a77  fafdcd668e3743c1bb461111dcafc2a4
# 13     003d66b6608740288d6cc97a6903f4f0  fafdcd668e3743c1bb461111dcafc2a4
# 20     004c5799adbf42868b9cff0396190900  f19421c1d4aa40978ebb69ca19b0e20d
# 21     004c5799adbf42868b9cff0396190900  fafdcd668e3743c1bb461111dcafc2a4
# 28     00715b6e55c3431cb56ff7307eb19675  0b1e1539f2cc45b7b9fa7c272da2e1d7
# ...                                 ...                               ...
# 44162  fff29fb549084123bd046dbc5ceb4faa  4d5c57ea9a6940dd891ad53e9dbe8da0
# 44163  fff29fb549084123bd046dbc5ceb4faa  ae264e3637204a6fb9bb56bc8210ddfd
# 44172  fff7576017104bcc8677a8d63322b5e1  fafdcd668e3743c1bb461111dcafc2a4
# 44176  fffad4f4828548d1b5583907f2e9906b  f19421c1d4aa40978ebb69ca19b0e20d
# 44178  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
#
#        time    age    income  days_as_member    F    M    O  reward  \
# 8       912  295.0  450000.0         13345.0  5.0  0.0  0.0    10.0
# 13     2184  156.0  438000.0         13170.0  6.0  0.0  0.0    12.0
# 20     2826  324.0  594000.0         15852.0  0.0  6.0  0.0    30.0
# 21     2364  324.0  594000.0         15852.0  0.0  6.0  0.0    12.0
# 28     1848  290.0  595000.0         10130.0  5.0  0.0  0.0    25.0
# ...     ...    ...       ...             ...  ...  ...  ...     ...
# 44162  2640  354.0  558000.0         12744.0  6.0  0.0  0.0    60.0
# 44163  2070  295.0  465000.0         10620.0  5.0  0.0  0.0    50.0
# 44172  1836  426.0  438000.0         12378.0  0.0  6.0  0.0    12.0
# 44176  1476  204.0  204000.0         14064.0  0.0  6.0  0.0    30.0
# 44178  4044  405.0  558000.0         21627.0  9.0  0.0  0.0    18.0
#
#        difficulty  duration  email  mobile  social  web  offer_completed  \
# 8            50.0      50.0    5.0     5.0     5.0  5.0                2
# 13           60.0      60.0    6.0     6.0     6.0  6.0                2
# 20           30.0      30.0    6.0     6.0     6.0  6.0                2
# 21           60.0      60.0    6.0     6.0     6.0  6.0                2
# 28          100.0      50.0    5.0     0.0     0.0  5.0                2
# ...           ...       ...    ...     ...     ...  ...              ...
# 44162        60.0      30.0    6.0     6.0     6.0  6.0                2
# 44163        50.0      35.0    5.0     5.0     5.0  0.0                2
# 44172        60.0      60.0    6.0     6.0     6.0  6.0                2
# 44176        30.0      30.0    6.0     6.0     6.0  6.0                2
# 44178        90.0      63.0    9.0     9.0     0.0  9.0                3
#
#        offer_viewed
# 8                 1
# 13                2
# 20                2
# 21                2
# 28                1
# ...             ...
# 44162             2
# 44163             1
# 44172             2
# 44176             2
# 44178             3
#
# [3579 rows x 18 columns]

# %%
offer_complete_df[offer_complete_df.offer_completed >2]
# Out:
#                                 user_id                          offer_id  \
# 248    018a49ffb8cf4812903e7c1f56fbb0b0  f19421c1d4aa40978ebb69ca19b0e20d
# 511    0335d274249f4eb6b3c51527f02a3216  4d5c57ea9a6940dd891ad53e9dbe8da0
# 660    040704e99ab84cd08977858fab9b9276  f19421c1d4aa40978ebb69ca19b0e20d
# 694    043bcfeacb874bbc837300701ce25870  ae264e3637204a6fb9bb56bc8210ddfd
# 737    0494aa6671414fab9837fa3cd45e72bc  0b1e1539f2cc45b7b9fa7c272da2e1d7
# ...                                 ...                               ...
# 43681  fcdc9e86b659499d882a4714ea53e974  ae264e3637204a6fb9bb56bc8210ddfd
# 43780  fd90af4b9b784b268efa9d349a762491  fafdcd668e3743c1bb461111dcafc2a4
# 43985  fee2d799672d4f81bfa3237207290f79  fafdcd668e3743c1bb461111dcafc2a4
# 44098  ff932c6f8bb641bd816955337d153676  f19421c1d4aa40978ebb69ca19b0e20d
# 44178  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
#
#        time    age    income  days_as_member    F    M    O  reward  \
# 248    3414  549.0  306000.0         21564.0  0.0  9.0  0.0    45.0
# 511    3144  189.0  666000.0         21636.0  9.0  0.0  0.0    90.0
# 660    4476  585.0  792000.0         18144.0  0.0  9.0  0.0    45.0
# 694    3642  630.0  648000.0         18306.0  9.0  0.0  0.0    90.0
# 737    2226  497.0  252000.0         18844.0  7.0  0.0  0.0    35.0
# ...     ...    ...       ...             ...  ...  ...  ...     ...
# 43681  2028  162.0  405000.0         21168.0  0.0  9.0  0.0    90.0
# 43780  2790  270.0  576000.0         16650.0  0.0  9.0  0.0    18.0
# 43985  1896  459.0  666000.0         23292.0  0.0  9.0  0.0    18.0
# 44098  1650  585.0  684000.0         25434.0  0.0  9.0  0.0    45.0
# 44178  4044  405.0  558000.0         21627.0  9.0  0.0  0.0    18.0
#
#        difficulty  duration  email  mobile  social  web  offer_completed  \
# 248          45.0      45.0    9.0     9.0     9.0  9.0                3
# 511          90.0      45.0    9.0     9.0     9.0  9.0                3
# 660          45.0      45.0    9.0     9.0     9.0  9.0                3
# 694          90.0      63.0    9.0     9.0     9.0  0.0                3
# 737         140.0      70.0    7.0     0.0     0.0  7.0                3
# ...           ...       ...    ...     ...     ...  ...              ...
# 43681        90.0      63.0    9.0     9.0     9.0  0.0                3
# 43780        90.0      90.0    9.0     9.0     9.0  9.0                3
# 43985        90.0      90.0    9.0     9.0     9.0  9.0                3
# 44098        45.0      45.0    9.0     9.0     9.0  9.0                3
# 44178        90.0      63.0    9.0     9.0     0.0  9.0                3
#
#        offer_viewed
# 248               3
# 511               3
# 660               3
# 694               3
# 737               1
# ...             ...
# 43681             3
# 43780             3
# 43985             3
# 44098             3
# 44178             3
#
# [270 rows x 18 columns]

# %%
offer_df[(offer_df.user_id == '0494aa6671414fab9837fa3cd45e72bc') & (offer_df.offer_id == '0b1e1539f2cc45b7b9fa7c272da2e1d7')]
# Out:
#                   event  time                          offer_id   age  \
# 10413    offer received     0  0b1e1539f2cc45b7b9fa7c272da2e1d7  71.0
# 37992      offer viewed    78  0b1e1539f2cc45b7b9fa7c272da2e1d7  71.0
# 51199   offer completed   150  0b1e1539f2cc45b7b9fa7c272da2e1d7  71.0
# 161076   offer received   408  0b1e1539f2cc45b7b9fa7c272da2e1d7  71.0
# 181994  offer completed   438  0b1e1539f2cc45b7b9fa7c272da2e1d7  71.0
# 211840   offer received   504  0b1e1539f2cc45b7b9fa7c272da2e1d7  71.0
# 290819  offer completed   648  0b1e1539f2cc45b7b9fa7c272da2e1d7  71.0
#
#                                  user_id   income  days_as_member    F    M  \
# 10413   0494aa6671414fab9837fa3cd45e72bc  36000.0          2692.0  1.0  0.0
# 37992   0494aa6671414fab9837fa3cd45e72bc  36000.0          2692.0  1.0  0.0
# 51199   0494aa6671414fab9837fa3cd45e72bc  36000.0          2692.0  1.0  0.0
# 161076  0494aa6671414fab9837fa3cd45e72bc  36000.0          2692.0  1.0  0.0
# 181994  0494aa6671414fab9837fa3cd45e72bc  36000.0          2692.0  1.0  0.0
# 211840  0494aa6671414fab9837fa3cd45e72bc  36000.0          2692.0  1.0  0.0
# 290819  0494aa6671414fab9837fa3cd45e72bc  36000.0          2692.0  1.0  0.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 10413   0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 37992   0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 51199   0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 161076  0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 181994  0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 211840  0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
# 290819  0.0     5.0        20.0      10.0   discount    1.0     0.0     0.0
#
#         web
# 10413   1.0
# 37992   1.0
# 51199   1.0
# 161076  1.0
# 181994  1.0
# 211840  1.0
# 290819  1.0

# %%
offer_df[(offer_df.user_id == '0020c2b971eb4e9188eac86d93036a77') & (offer_df.offer_id == 'fafdcd668e3743c1bb461111dcafc2a4')]
# Out:
#                   event  time                          offer_id   age  \
# 1889     offer received     0  fafdcd668e3743c1bb461111dcafc2a4  59.0
# 18431      offer viewed    12  fafdcd668e3743c1bb461111dcafc2a4  59.0
# 31327   offer completed    54  fafdcd668e3743c1bb461111dcafc2a4  59.0
# 112684   offer received   336  fafdcd668e3743c1bb461111dcafc2a4  59.0
# 218771  offer completed   510  fafdcd668e3743c1bb461111dcafc2a4  59.0
#
#                                  user_id   income  days_as_member    F    M  \
# 1889    0020c2b971eb4e9188eac86d93036a77  90000.0          2669.0  1.0  0.0
# 18431   0020c2b971eb4e9188eac86d93036a77  90000.0          2669.0  1.0  0.0
# 31327   0020c2b971eb4e9188eac86d93036a77  90000.0          2669.0  1.0  0.0
# 112684  0020c2b971eb4e9188eac86d93036a77  90000.0          2669.0  1.0  0.0
# 218771  0020c2b971eb4e9188eac86d93036a77  90000.0          2669.0  1.0  0.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 1889    0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 18431   0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 31327   0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 112684  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 218771  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
#
#         web
# 1889    1.0
# 18431   1.0
# 31327   1.0
# 112684  1.0
# 218771  1.0

# %%
offer_df[(offer_df.user_id == 'edc7b04392144da9979f3077095f268a') & (offer_df.offer_id == 'fafdcd668e3743c1bb461111dcafc2a4')]
# Out:
#                   event  time                          offer_id   age  \
# 64630    offer received   168  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 74568      offer viewed   180  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 91966   offer completed   234  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 122267   offer received   336  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 141346     offer viewed   372  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 158736   offer received   408  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 190920     offer viewed   462  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 194743  offer completed   474  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 201278  offer completed   498  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 209549   offer received   504  fafdcd668e3743c1bb461111dcafc2a4  64.0
# 244711  offer completed   570  fafdcd668e3743c1bb461111dcafc2a4  64.0
#
#                                  user_id   income  days_as_member    F    M  \
# 64630   edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 74568   edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 91966   edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 122267  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 141346  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 158736  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 190920  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 194743  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 201278  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 209549  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
# 244711  edc7b04392144da9979f3077095f268a  51000.0          3027.0  1.0  0.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 64630   0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 74568   0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 91966   0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 122267  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 141346  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 158736  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 190920  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 194743  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 201278  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 209549  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
# 244711  0.0     2.0        10.0      10.0   discount    1.0     1.0     1.0
#
#         web
# 64630   1.0
# 74568   1.0
# 91966   1.0
# 122267  1.0
# 141346  1.0
# 158736  1.0
# 190920  1.0
# 194743  1.0
# 201278  1.0
# 209549  1.0
# 244711  1.0

# %%
offer_df[(offer_df.user_id == '1c8cf4af93464dcaa971cfcffc2cc1e5') & (offer_df.offer_id == '2298d6c36e964ae4a3e7e9706d1fb8c2')]
# Out:
#                   event  time                          offer_id   age  \
# 9430     offer received     0  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 17478   offer completed     6  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 25652      offer viewed    30  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 62636    offer received   168  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 74147      offer viewed   180  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 80916   offer completed   198  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 210863   offer received   504  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 220863     offer viewed   510  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 229574  offer completed   528  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 254325   offer received   576  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 267759     offer viewed   588  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
# 287023  offer completed   636  2298d6c36e964ae4a3e7e9706d1fb8c2  73.0
#
#                                  user_id   income  days_as_member    F    M  \
# 9430    1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 17478   1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 25652   1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 62636   1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 74147   1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 80916   1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 210863  1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 220863  1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 229574  1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 254325  1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 267759  1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
# 287023  1c8cf4af93464dcaa971cfcffc2cc1e5  97000.0          2161.0  0.0  1.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 9430    0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 17478   0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 25652   0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 62636   0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 74147   0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 80916   0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 210863  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 220863  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 229574  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 254325  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 267759  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
# 287023  0.0     3.0         7.0       7.0   discount    1.0     1.0     1.0
#
#         web
# 9430    1.0
# 17478   1.0
# 25652   1.0
# 62636   1.0
# 74147   1.0
# 80916   1.0
# 210863  1.0
# 220863  1.0
# 229574  1.0
# 254325  1.0
# 267759  1.0
# 287023  1.0

# %%
offer_df[(offer_df.user_id == '073fce5708884b30a28b65b3cb15a919') & (offer_df.offer_id == '9b98b8c7a33c4b65b9aebfe6a799e6d9')]
# Out:
#                   event  time                          offer_id   age  \
# 2268     offer received     0  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 13189      offer viewed     0  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 38457   offer completed    84  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 55466    offer received   168  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 66499      offer viewed   168  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 87438   offer completed   222  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 152857   offer received   408  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 168232  offer completed   414  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 171687     offer viewed   420  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 203692   offer received   504  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 214882     offer viewed   504  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
# 214884  offer completed   504  9b98b8c7a33c4b65b9aebfe6a799e6d9  58.0
#
#                                  user_id   income  days_as_member    F    M  \
# 2268    073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 13189   073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 38457   073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 55466   073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 66499   073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 87438   073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 152857  073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 168232  073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 171687  073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 203692  073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 214882  073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
# 214884  073fce5708884b30a28b65b3cb15a919  96000.0          2354.0  0.0  1.0
#
#           O  reward  difficulty  duration offer_type  email  mobile  social  \
# 2268    0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 13189   0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 38457   0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 55466   0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 66499   0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 87438   0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 152857  0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 168232  0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 171687  0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 203692  0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 214882  0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
# 214884  0.0     5.0         5.0       7.0       bogo    1.0     1.0     0.0
#
#         web
# 2268    1.0
# 13189   1.0
# 38457   1.0
# 55466   1.0
# 66499   1.0
# 87438   1.0
# 152857  1.0
# 168232  1.0
# 171687  1.0
# 203692  1.0
# 214882  1.0
# 214884  1.0

# %% [markdown]
# #### Write data to parquet files

# %%
# write output data to parquet files
# combined.to_parquet('data/combined.parquet', engine='pyarrow')
# offer_df.to_parquet('data/offer_df.parquet', engine='pyarrow')
offer_complete_df.to_parquet('data/offer_complete_df.parquet', engine='pyarrow')
transaction_df.to_parquet('data/transaction_df.parquet', engine='pyarrow')

# %%
# drop all the id columns as we do not need them for modelling
# offer_complete_df.drop(columns=['user_id', 'offer_id'], inplace=True)
